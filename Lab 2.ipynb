# %% [markdown]
# # Q1

# %%
my_name = "Christina Ward"

# %%
print(my_name)
# Out:
# Christina Ward

# %% [markdown]
# # Q2

# %%
my_id = 193485

# %%
print(my_id)
# Out:
# 193485

# %% [markdown]
# # Q3

# %%
my_id_str = "193485"

# %%
print(my_id_str)
# Out:
# 193485

# %% [markdown]
# # Q4

# %%
my_name + my_id
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-9689ed831595> in <module>()
# ----> 1 my_name + my_id
#
# TypeError: must be str, not int

# %% [markdown]
# #### Cannot add, one is an integer and one is a string

# %% [markdown]
# # Q5

# %%
my_name + my_id_str
# Out:
# 'Christina Ward193485'

# %% [markdown]
# # Q6

# %%
"hello, world. This is my first python string.".split(".")
# Out:
# ['hello, world', ' This is my first python string', '']

# %% [markdown]
# # Q7

# %%
str_list = ["a","b","c","d","e"]
str_list.sort()

# %%
print(str_list)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# # Q8

# %%
str_list.append("f")

# %%
print(str_list)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %% [markdown]
# # Q9

# %%
str_list.remove("d")

# %%
print(str_list)
# Out:
# ['a', 'b', 'c', 'e', 'f']

# %% [markdown]
# # Q10

# %%
str_list[2]
# Out:
# 'c'

# %% [markdown]
# # Q11

# %%
num_list = [12,32,43,35]
str_list + num_list
# Out:
# ['a', 'b', 'c', 'e', 'f', 12, 32, 43, 35]

# %% [markdown]
# # Q12

# %%
my_dict = {"name":"Christina", "id":my_id}
print(my_dict)
# Out:
# {'name': 'Christina', 'id': 193485}

# %% [markdown]
# # Q13

# %%
my_dict["name"]="Ward"
print(my_dict)
# Out:
# {'name': 'Ward', 'id': 193485}

# %% [markdown]
# # Q14

# %%
my_dict.get("id")
# Out:
# 193485

# %% [markdown]
# # Q15

# %%
my_dict["id"]="153535"
print(my_dict)
# Out:
# {'name': 'Ward', 'id': '153535'}

# %% [markdown]
# # Q16

# %%
my_dict['num_list'] = num_list
print(my_dict)
# Out:
# {'name': 'Ward', 'id': '153535', 'num_list': [12, 32, 43, 35]}

# %% [markdown]
# Added num_list to dictionary
